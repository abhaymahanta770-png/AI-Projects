# %%
import numpy as np
import pandas as pd

# %%
adult = pd.read_csv(r"C:\Users\USER-1\OneDrive\Desktop\Data set\adult (1)\adult.data",header=None)
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
adult.columns =['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','nativecountry','income']
adult
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# nativecountry     0
# income            0
# dtype: int64

# %%
for i in adult.columns:
    print(i,":",adult[i].unique(),"\n")
# Out:
# age : [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# workclass : [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# fnlwgt : [ 77516  83311 215646 ...  34066  84661 257302]
#
# education : [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# education-num : [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital-status : [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation : [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
# ...

# %%
for i in adult.columns:
    print(i,':',sum((adult[i])==' ?'))
# Out:
# age : 0
# workclass : 1836
# fnlwgt : 0
# education : 0
# education-num : 0
# marital-status : 0
# occupation : 1843
# relationship : 0
# race : 0
# sex : 0
# capital-gain : 0
# capital-loss : 0
# hours-per-week : 0
# nativecountry : 583
# income : 0

# %%
adult.replace(' ?', np.nan, inplace=True)

# %%
adult.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# nativecountry      583
# income               0
# dtype: int64

# %%
d=adult.describe(include="all")
d
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     30725  3.256100e+04     32561   32561.000000
# unique           NaN         8           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital-status       occupation relationship    race    sex  \
# ...

# %%
adult.workclass.replace(np.nan,d['workclass'][2],inplace=True)
# Out:
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\418787237.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adult.workclass.replace(np.nan,d['workclass'][2],inplace=True)
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\418787237.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
adult.occupation.replace(np.nan,d['occupation'][2],inplace=True)
# Out:
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\888463030.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adult.occupation.replace(np.nan,d['occupation'][2],inplace=True)
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\888463030.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
adult.nativecountry.replace(np.nan,d['nativecountry'][2],inplace=True)
# Out:
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\332733087.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   adult.nativecountry.replace(np.nan,d['nativecountry'][2],inplace=True)
# C:\Users\USER-1\AppData\Local\Temp\ipykernel_12632\332733087.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
adult.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# nativecountry     object
# income            object
# dtype: object

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# nativecountry     0
# income            0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as pit

# %%
sns.countplot(x='income', data=adult)
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
sns.histplot(adult['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(adult['hours-per-week'], kde=True)
# Out:
# <Axes: xlabel='hours-per-week', ylabel='Count'>

# %%
sns.histplot(adult['capital-gain'], kde=True)
# Out:
# <Axes: xlabel='capital-gain', ylabel='Count'>

# %%
sns.histplot(adult['capital-loss'], kde=True)
# Out:
# <Axes: xlabel='capital-loss', ylabel='Count'>

# %%
sns.boxplot(x='income', y='age', data=adult)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
sns.countplot(x='sex', hue='income', data=adult)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
pit.figure(figsize=(50,50))
sns.countplot(x='occupation', hue='income', data=adult)
pit.show()

# %%
pit.figure(figsize=(10,6))
sns.countplot(x='education',hue='income',data=adult)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.countplot(x='marital-status',hue='income',data=adult)
# Out:
# <Axes: xlabel='marital-status', ylabel='count'>

# %%
sns.countplot(x='nativecountry',hue='income',data=adult)
# Out:
# <Axes: xlabel='nativecountry', ylabel='count'>

# %%
sns.countplot(x='relationship',hue='income',data=adult)
# Out:
# <Axes: xlabel='relationship', ylabel='count'>

# %%
sns.countplot(x='race',hue='income',data=adult)
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
sns.heatmap(adult.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(adult[['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','nativecountry','income']
             ])
pit.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in adult.columns:
    if adult[i].dtypes =='object':
        adult[i]= le.fit_transform(adult[i])

# %%
adult.dtypes
# Out:
# age               int64
# workclass         int64
# fnlwgt            int64
# education         int64
# education-num     int64
# marital-status    int64
# occupation        int64
# relationship      int64
# race              int64
# sex               int64
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# nativecountry     int64
# income            int64
# dtype: object

# %%
ip=adult.drop(['income','fnlwgt',],axis=1)
op=adult.income

# %%
ip.head()
# Out:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0   39          6          9             13               4           0
# 1   50          5          9             13               2           3
# 2   38          3         11              9               0           5
# 3   53          3          1              7               2           5
# 4   28          3          9             13               2           9
#
#    relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0             1     4    1          2174             0              40
# 1             0     4    1             0             0              13
# 2             1     4    1             0             0              40
# 3             0     2    1             0             0              40
# 4             5     2    0             0             0              40
#
#    nativecountry
# 0             38
# 1             38
# 2             38
# 3             38
# ...

# %%
op.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(ip,op,train_size=0.8)

# %%
xtrain.shape
# Out:
# (26048, 13)

# %%
xtest.shape
# Out:
# (6513, 13)

# %%
xtrain
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 19822   29          3          8             11               2           2
# 21740   26          3          0              6               2           2
# 8141    19          3         15             10               4          11
# 9749    51          1         14             15               4           9
# 8884    21          3          4              3               4           8
# ...    ...        ...        ...            ...             ...         ...
# 14982   66          3         15             10               0           9
# 24442   54          3          9             13               2          11
# 5091    35          3         11              9               0           3
# 13050   19          1         15             10               4           0
# 13088   25          3          8             11               4           0
#
# ...

# %%
xtest
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 13360   35          5          9             13               0           3
# 10904   39          0         11              9               2           0
# 15722   50          3         11              9               2           2
# 10286   51          0         10             16               2           9
# 216     50          3          7             12               0          11
# ...    ...        ...        ...            ...             ...         ...
# 28840   21          3         11              9               4           8
# 27774   19          3         15             10               4           9
# 14954   35          3          7             12               4          10
# 23509   62          3         11              9               2           4
# 32459   85          3          9             13               2           3
#
# ...

# %%
ytrain
# Out:
# 19822    1
# 21740    0
# 8141     0
# 9749     0
# 8884     0
#         ..
# 14982    0
# 24442    1
# 5091     0
# 13050    0
# 13088    0
# Name: income, Length: 26048, dtype: int64

# %%
ytest
# Out:
# 13360    0
# 10904    0
# 15722    0
# 10286    1
# 216      0
#         ..
# 28840    0
# 27774    0
# 14954    0
# 23509    1
# 32459    0
# Name: income, Length: 6513, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
xtrain = sc.fit_transform(xtrain)
xtrain
# Out:
# array([[-0.70148534, -0.08385215, -0.59621746, ..., -0.21720599,
#         -0.0378344 ,  0.26094342],
#        [-0.92180153, -0.08385215, -2.66357821, ..., -0.21720599,
#          1.17784452,  0.26094342],
#        [-1.43587263, -0.08385215,  1.2127232 , ..., -0.21720599,
#         -0.4430607 ,  0.26094342],
#        ...,
#        [-0.26085297, -0.08385215,  0.17904282, ..., -0.21720599,
#         -0.0378344 ,  0.26094342],
#        [-1.43587263, -1.88672524,  1.2127232 , ..., -0.21720599,
#         -2.06396593,  0.26094342],
#        [-0.99524026, -0.08385215, -0.59621746, ..., -0.21720599,
#         -0.0378344 ,  0.26094342]])

# %%
xtest=sc.transform(xtest)
xtest
# Out:
# array([[-0.26085297,  1.71902094, -0.33779737, ..., -0.21720599,
#         -1.25351332,  0.26094342],
#        [ 0.03290195, -2.78816178,  0.17904282, ..., -0.21720599,
#          0.77261822,  0.26094342],
#        [ 0.84072797, -0.08385215,  0.17904282, ..., -0.21720599,
#         -0.0378344 ,  0.26094342],
#        ...,
#        [-0.26085297, -0.08385215, -0.85463755, ..., -0.21720599,
#         -0.0378344 ,  0.26094342],
#        [ 1.72199272, -0.08385215,  0.17904282, ..., -0.21720599,
#         -0.0378344 ,  0.26094342],
#        [ 3.41108349, -0.08385215, -0.33779737, ..., -0.21720599,
#         -3.03650907, -1.06430904]])

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred = lr.predict(xtest)
pred
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
ytest
# Out:
# 13360    0
# 10904    0
# 15722    0
# 10286    1
# 216      0
#         ..
# 28840    0
# 27774    0
# 14954    0
# 23509    1
# 32459    0
# Name: income, Length: 6513, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(ytest,pred)
cm
# Out:
# array([[4697,  290],
#        [ 830,  696]])

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()
pit.show()

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc = accuracy_score(ytest,pred)
rec = recall_score(ytest,pred)
pre = precision_score(ytest,pred)
f1 = f1_score(ytest,pred)

# %%
print(f"Accuracy:{acc}\nRecall:{rec}\nPrecision:{pre}\nF1 Score:{f1}")
# Out:
# Accuracy:0.828036235221864
# Recall:0.45609436435124506
# Precision:0.7058823529411765
# F1 Score:0.554140127388535

# %%
df = pd.DataFrame({'Ytest':list(ytest),'Prediction':pred})
df
# Out:
#       Ytest  Prediction
# 0         0           0
# 1         0           0
# 2         0           0
# 3         1           1
# 4         0           0
# ...     ...         ...
# 6508      0           0
# 6509      0           0
# 6510      0           0
# 6511      1           1
# 6512      0           1
#
# [6513 rows x 2 columns]

# %%
sns.lmplot(x='Ytest',y="Prediction",data=df,logistic=True)
pit.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
pred1 = knn.predict(xtest)
pred1
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(ytest,pred1)
cm
# Out:
# array([[4534,  453],
#        [ 630,  896]])

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot(cmap='Purples')
pit.show()

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc = accuracy_score(ytest,pred1)
rec = recall_score(ytest,pred1)
pre = precision_score(ytest,pred1)
f1 = f1_score(ytest,pred1)

# %%
print(f"Accuracy:{acc}\nRecall:{rec}\nPrecision:{pre}\nF1 Score:{f1}")
# Out:
# Accuracy:0.8337171810225702
# Recall:0.5871559633027523
# Precision:0.6641957005189029
# F1 Score:0.6233043478260869

# %%
from sklearn import svm
sv=svm.SVC(kernel='rbf',C=100,gamma=0.01)
sv.fit(xtrain,ytrain)
# Out:
# SVC(C=100, gamma=0.01)

# %%
pred2 = sv.predict(xtest)
pred2
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm= confusion_matrix(ytest,pred2)
cm
# Out:
# array([[4668,  319],
#        [ 663,  863]])

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot(cmap='Purples')
pit.show()

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc = accuracy_score(ytest,pred2)
rec = recall_score(ytest,pred2)
pre = precision_score(ytest,pred2)
f1 = f1_score(ytest,pred2)

# %%
print(f"Accuracy:{acc}\nRecall:{rec}\nPrecision:{pre}\nF1 Score:{f1}")
# Out:
# Accuracy:0.8492246276677414
# Recall:0.5655307994757536
# Precision:0.7301184433164128
# F1 Score:0.6373707533234859

# %%
#Navie baye's
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
yp1=nb.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc1=accuracy_score(ytest,yp1)
recall1=recall_score(ytest,yp1)
precision1=precision_score(ytest,yp1)
f11=f1_score(ytest,yp1)

# %%
print(acc1)
print(recall1)
print(precision1)
print(f11)
# Out:
# 0.8066943037002917
# 0.3394495412844037
# 0.6736020806241872
# 0.4514161220043573

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(xtrain,ytrain)
y_pred = clf.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc=accuracy_score(ytest,y_pred)
recall=recall_score(ytest,y_pred)
precision=precision_score(ytest,y_pred)
f1=f1_score(ytest,y_pred)

# %%
print(acc)
print(recall)
print(precision)
print(f1)
# Out:
# 0.8152924919391985
# 0.6028833551769331
# 0.6064601186552406
# 0.6046664475846204

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
clf1=RandomForestClassifier(criterion='entropy',random_state=0)
clf1.fit(xtrain,ytrain)
yp5=clf1.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc2=accuracy_score(ytest,yp5)
recall2=recall_score(ytest,yp5)
precision2=precision_score(ytest,yp5)
f12=f1_score(ytest,yp5)

# %%
print(acc2)
print(recall2)
print(precision2)
print(f12)
# Out:
# 0.8496852448948258
# 0.6323722149410222
# 0.6977584960231381
# 0.6634582330697835

# %%
#adaboost algorithm
from sklearn.ensemble import AdaBoostClassifier
a1=AdaBoostClassifier(n_estimators=50,learning_rate=0.1)
a1.fit(xtrain,ytrain)
yp6=a1.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc3=accuracy_score(ytest,yp6)
recall3=recall_score(ytest,yp6)
precision3=precision_score(ytest,yp6)
f13=f1_score(ytest,yp6)

# %%
print(acc3)
print(recall3)
print(precision3)
print(f13)
# Out:
# 0.7976354982343006
# 0.13958060288335516
# 0.9770642201834863
# 0.24426605504587157

# %%
from sklearn.ensemble import GradientBoostingClassifier
a1=AdaBoostClassifier(n_estimators=50,learning_rate=0.3,estimator=nb)
a1.fit(xtrain,ytrain)
yp7=a1.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc3=accuracy_score(ytest,yp7)
recall3=recall_score(ytest,yp7)
precision3=precision_score(ytest,yp7)
f13=f1_score(ytest,yp7)

# %%
print(acc3)
print(recall3)
# Out:
# 0.8378627360663289
# 0.5091743119266054
